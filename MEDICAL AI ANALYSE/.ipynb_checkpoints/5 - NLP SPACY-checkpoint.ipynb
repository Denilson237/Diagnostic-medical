# %% [markdown]
# ### Importations

# %%
import pandas as pd
import numpy as np
import re
from nltk.tokenize import word_tokenize
from unidecode import unidecode
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer,PorterStemmer

# %% [markdown]
# ### Lecture du dataset

# %%
df = pd.read_csv("Ressources/RessourcesAnalyse/DatasetClean.csv")
df.head()
# Out:
#             Maladies                                          Symptomes  \
# 0       endométriose  douleurs pelviennes intenses,douleurs pendant ...
# 1  anémie ferriprive  fatigue intense,faiblesse générale,palpitation...
# 2  trouble bipolaire  variations extrêmes d'humeur,irritabilité ,ins...
# 3    maladie de lyme  éruption cutanée en forme de cible (érythème m...
# 4      schizophrénie  hallucinations auditives,hallucinations olfact...
#
#                                           Traitement  \
# 0  médicaments anti-inflammatoires,chirurgie,trai...
# 1  suppléments de fer,ajustement du régime alimen...
# 2  médicaments stabilisateurs de l'humeur,thérapi...
# 3  antibiotiques,médicaments anti-inflammatoires,...
# 4  antipsychotiques,thérapie psychosociale,hospit...
#
#                                              Examens
# 0  imagerie médicale (échographie pelvienne),lapa...
# 1  analyse de sang (taux de fer),numération sangu...
# 2      évaluation psychiatrique,entretiens cliniques
# 3  test sanguin (détection d'anticorps),analyse d...
# 4  évaluation psychiatrique,entretiens cliniques,...

# %% [markdown]
# ## I - Nettoyage de données

# %%
stop_words = stopwords.words('french')
lemmatizer = WordNetLemmatizer()

ps = PorterStemmer()

# %%
new_stopwords =["facilement","tres","pendant"]

stop_words.extend(new_stopwords)

# %%
def Cleaning(text):
    
    def remove_s(word):
        if word.endswith('s'):
            return word[:-1]
        if word.endswith('ment'):
            return word[:-4]
        else:
            return word
        
    liste2 = ["abdomin ","abdomen","abdominal"]
    liste1 = ["douleur","mal"]
        
    # Supprimer des ponctuations
    text = re.sub("[^\w\s]", " ", text)
   
    text = ' '.join([lemmatizer.lemmatize(word.lower()) for word in word_tokenize(text) if word.isalnum() and word.lower() not in stop_words])
    
    # supprimer les chiffres
    text = re.sub("\d", "", text)
    
    #text = [remove_s(word) for word in text]
    
    text = text.replace("ee ","e ")
    text = text.replace("cutane","peau")
    
    for i in liste2:
        text = text.replace(i,"ventre ")
        
    text = list(set(text.split()))
    
    text = ' '.join([remove_s(word) for word in text])
    
    for i in liste1:
        text = text.replace(i,"maux")
    
    text = text.replace(" e "," ")
    return text

# %%
df["Symptomes_lem_token"] = df["Symptomes"].apply(lambda x: Cleaning(x))
df["Symptomes_lem_token"]
# Out:
# 0      maux fatigue exercice intestinaux menstruel in...
# 1      fatigue lisse étourdissement main langue diffi...
# 2      rapide délirante augmentation sexuelle décisio...
# 3      maux fatigue forme musculaire paralysie lympha...
# 4      émousse délirante mémoire affectif désorganisé...
#                              ...
# 96                      maux fatigue tête frisson fièvre
# 97          éruption maux musculaire fièvre toux cutanée
# 98               maux fatigue tête enflé ganglion fièvre
# 99      fatigue paupière trouble fièvre cardiaque gonfle
# 100    rate enflure poid perte fièvre foie anémie pro...
# Name: Symptomes_lem_token, Length: 101, dtype: object

# %% [markdown]
# ## III -  Calcul de similarité

# %%
liste_symptomes ="fievres fatigue frissons maux facilement tête"
liste_symptomes = Cleaning(liste_symptomes)

# %%
import spacy

# Charger le modèle linguistique français avec des vecteurs de mots
nlp = spacy.load('fr_core_news_md')

liste_symptomes = nlp(liste_symptomes)

# %%
cosine_similarite = []

for i in range(len(df["Symptomes_lem_token"])):
    
    doc = nlp(df['Symptomes_lem_token'][i])
    
    cosine_similaritie = doc.similarity(liste_symptomes)
    
    cosine_similarite.append(cosine_similaritie)

# %%
cosine_similaritie = np.array(cosine_similarite)
cosine_similaritie
# Out:
# array([0.61765711, 0.74924506, 0.53719215, 0.75618754, 0.472206  ,
#        0.73170917, 0.72621213, 0.68427724, 0.7363549 , 0.837056  ,
#        0.74336253, 0.72602673, 0.67744933, 0.78875474, 0.71441516,
#        0.82710023, 0.78643023, 0.80600264, 0.80851262, 0.67401403,
#        0.73182821, 0.70612302, 0.57441591, 0.76301736, 0.75061754,
#        0.60568277, 0.58720548, 0.68861632, 0.68646175, 0.83636448,
#        0.62666079, 0.72714423, 0.82907244, 0.70829166, 0.83691497,
#        0.65412707, 0.7808528 , 0.60560128, 0.67630347, 0.68015954,
#        0.69112177, 0.40540237, 0.52387048, 0.69286046, 0.75806751,
#        0.81793195, 0.76174029, 0.75474674, 0.59120357, 0.66484581,
#        0.62780598, 0.7564414 , 0.628963  , 0.7684921 , 0.78507042,
#        0.71540835, 0.73605219, 0.78507042, 0.73486744, 0.77104624,
#        0.77039656, 0.79216623, 0.56942144, 0.69009277, 0.76848895,
#        0.6088391 , 0.75981812, 0.75921146, 0.66819427, 0.72950717,
#        0.64437436, 0.788338  , 0.76924479, 0.70922922, 0.67339739,
#        0.64413484, 0.81224151, 0.71822792, 0.75741863, 0.91293596,
#        0.82247896, 0.74631061, 0.69829522, 0.6996743 , 0.91547346,
#        0.60779683, 0.63010259, 0.5722467 , 0.74246715, 0.8197765 ,
#        0.86779109, 0.64915936, 0.63104255, 0.77127272, 0.55761266,
#        0.6678591 , 1.00000002, 0.76229522, 0.91585805, 0.78878705,
#        0.65708637])

# %%
df['Similarite_%'] = 100*cosine_similaritie.flatten()

# %%
df['Similarite_%']
# Out:
# 0       61.765711
# 1       74.924506
# 2       53.719215
# 3       75.618754
# 4       47.220600
#           ...
# 96     100.000002
# 97      76.229522
# 98      91.585805
# 99      78.878705
# 100     65.708637
# Name: Similarite_%, Length: 101, dtype: float64

# %%
df_tri = df.sort_values(by='Similarite_%', ascending=False)

# %%
print(liste_symptomes)
df_tri[:20]
# Out:
# maux fatigue fievre tête frisson
#                              Maladies  \
# 96                          paludisme
# 98           trypanosomiase africaine
# 84                          varicelle
# 79                          méningite
# 90    accidents vasculaires cérébraux
# 9                        toxoplasmose
# 34       tréponématose non vénérienne
# 29         chancre mou (ulcère molle)
# 32  mycobacterium avium complex (mac)
# 15                           amibiase
# 80                             angine
# 89         maladies cardiovasculaires
# 45                       fibromyalgie
# 76                          pneumonie
# 18                           syphilis
# 17                               sida
# 61               cancer de l'œsophage
# 99                  maladie de chagas
# 13                        tuberculose
# 71              cancer de la thyroïde
#
#                                             Symptomes  \
# 96               fièvre,frissons,maux de tête,fatigue
# 98       fièvre,fatigue,maux de tête,ganglions enflés
# 84  éruption cutanée avec des démangeaisons,fièvre...
# 79  raideur de la nuque,maux de tête sévères fièvr...
# 90  engourdissement,faiblesse soudaine,confusion,m...
# 9   gonflement des ganglions lymphatiques,fièvre,m...
# 34  lésions cutanées (chancre),ganglions lymphatiq...
# 29  ulcération génitale indolore,ganglions lymphat...
# 32  fièvre,sueurs nocturnes,fatigue,perte de poids...
# 15  diarrhée,douleurs abdominales,crampes abdomina...
# 80  maux de gorge,difficulté à avaler,fièvre gangl...
# 89  douleur thoracique,essoufflement,fatigue,palpi...
# 45  douleurs musculaires diffuses,fatigue générali...
# 76  fièvre,toux avec expectorations,douleur thorac...
# 18  chancre indolore (ulcération),éruption cutanée...
# 17  fatigue,fièvre,gonflement des ganglions lympha...
# 61  difficulté à avaler (dysphagie),douleur ou sen...
# 99  fièvre,fatigue,gonflement des paupières,troubl...
# 13  toux persistante,expectorations de sang,fatigu...
# 71  gonflement ou bosse dans le cou,changements da...
#
#                                            Traitement  \
# 96                               antipaludiques,repos
# 98         médicaments antiparasitaires,antibiotiques
# 84  antihistaminiques,antipyrétiques,calamine pour...
# 79  antibiotiques,traitement de support,hospitalis...
# 90  thérapie de revascularisation,médicaments anti...
# 9        antibiotiques,repos,traitement symptomatique
# 34                            pénicilline,doxycycline
# 29                             azithromycine,céfixime
# 32             antibiotiques,traitement symptomatique
# 15       antiparasitaires,antibiotiques,réhydratation
# 80  antibiotiques (si bactérienne),antalgiques,gar...
# 89  médicaments antiplaquettaires,médicaments pour...
# 45  médicaments analgésiques,thérapie physique,thé...
# 76                 antibiotiques,antipyrétiques,repos
# 18                            pénicilline,doxycycline
# 17                          traitement antirétroviral
# 61             chirurgie,chimiothérapie,radiothérapie
# 99  médicaments antiparasitaires,médicaments pour ...
# 13  antibiotiques (multithérapie),isolement,traite...
# 71             chirurgie,thyroïdectomie,radiothérapie
#
#                                               Examens  \
# 96                     test de dépistage du paludisme
# 98                                       test sanguin
# 84  les symptômes sont souvent suffisants pour le ...
# 79  ponction lombaire,analyse de liquide céphalora...
# 90  tomographie par ordinateur (tdm) du cerveau,im...
# 9   test sanguin (détection d'anticorps),biopsie e...
# 34  test de dépistage de la tréponématose non véné...
# 29  test de dépistage du chancre mou,examen micros...
# 32         test de dépistage du mac,imagerie médicale
# 15  analyse de selles,imagerie médicale,tests sang...
# 80  examen de la gorge,analyse de la gorge pour dé...
# 89        électrocardiogramme (ecg),échocardiographie
# 45  aucun test spécifique,diagnostic basé sur les ...
# 76            radiographie pulmonaire,analyse de sang
# 18           test de la syphilis,examen au microscope
# 17  test de dépistage du vih,compte de lymphocytes...
# 61  endoscopie digestive haute,biopsie,imagerie mé...
# 99             test sanguin,électrocardiogramme (ecg)
# 13  radiographie thoracique,test cutané à la tuber...
# 71  échographie thyroïdienne,scintigraphie thyroïd...
#
#                                   Symptomes_lem_token  Similarite_%
# 96                   maux fatigue tête frisson fièvre    100.000002
# 98            maux fatigue tête enflé ganglion fièvre     91.585805
# 84  éruption maux fatigue tête fièvre démangeaison...     91.547346
# 79    maux raideur confusion tête fièvre nuque sévère     91.293596
# 90  maux confusion soudaine tête faiblesse sévère ...     86.779109
# 9   maux fatigue musculaire lymphatique fièvre mau...     83.705600
# 34  lésion maux fatigue maux musculaire éruption t...     83.691497
# 29  maux maux fatigue musculaire éruption tête enf...     83.636448
# 32  maux fatigue poid nocturne sueur persistante o...     82.907244
# 15  maux fatigue vomissement glaireuse poid perte ...     82.710023
# 80  maux difficulté gorge enflé ganglion fièvre av...     82.247896
# 89      fatigue essouffle thoracique palpitation maux     81.977650
# 45  maux maux fatigue cérébral musculaire problème...     81.793195
# 76  difficulté expectoration respirer fièvre thora...     81.224151
# 18  maux fatigue musculaire paume poid enflé lymph...     80.851262
# 17  maux fatigue musculaire poid mémoire lymphatiq...     80.600264
# 61  difficulté inexpliquée sternum poid dysphagie ...     79.216623
# 99   fatigue paupière trouble fièvre cardiaque gonfle     78.878705
# 13  maux sang fatigue inexpliquée essouffle thorac...     78.875474
# 71  bosse difficulté changement voix avaler cou go...     78.833800
